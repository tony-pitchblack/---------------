# %%
import numpy as np
import seaborn as sns
from scipy.stats.mstats import winsorize

# %%
a = np.random.rand(5, 5)
a
# Out:
# array([[0.82419306, 0.35421228, 0.76700088, 0.71344969, 0.73938514],
#        [0.09992713, 0.22343589, 0.93836198, 0.78775214, 0.80093902],
#        [0.86948273, 0.9273763 , 0.16991144, 0.67617522, 0.20744335],
#        [0.19819134, 0.2179792 , 0.7751243 , 0.54833673, 0.68377738],
#        [0.52900452, 0.80660915, 0.24727918, 0.95206713, 0.42169879]])

# %%
sns.boxplot(a)
# Out:
# <Axes: >

# %%
lim = 0.2
a_w = winsorize(a, limits=[lim, lim])
sns.boxplot(a_w)
# Out:
# <Axes: >
